# %%
import statistics
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import re
import glob
import os

# %%
players = [
    "4900668/cole-anderson",
    "4900669/ariel-bland",
    "4702594/gage-gomez",
    #'4900670/henry-hartwell',
    #'4592899/zach-harvey',
    #"4397646/robinson-idehen",
    #"4431850/jakov-kukic",
    #"4900671/ajay-mitchell",
    #"4397643/jay-nagle",
    #"4397104/miles-norris",
    #"4900672/david-pickles",
    #"4431795/josh-pierre-louis",
    #"4397676/ajare-sanni",
    #"4900673/max-sheldon",
    "4397644/amadou-sow",
    #"4397642/sekou-toure",
    #"4397521/calvin-wishart",
]

# %%
lst = []
for player in players:
    url = f"https://www.espn.com/mens-college-basketball/player/gamelog/_/id/{player}"
    html = pd.read_html(url)
    stats = pd.DataFrame(html[0])
    stats["Player"] = player[8:]
    stats = stats[:-1]  # drops last row which is an averages row
    lst.append(stats)

# %%
df = pd.concat(lst)
df
# Out:
#                                                  Date  \
# 0                                            Fri 3/11
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                            Thu 3/10
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                             Thu 3/3
# ..                                                ...
# 25                                          Mon 11/29
# 26                                          Wed 11/24
# 27                                          Sat 11/20
# 28                                          Mon 11/15
# 29                                          Wed 11/10
#
#                                                   OPP  \
# 0                                              vsLBSU
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                               vsUCI
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                               vsHAW
# ..                                                ...
# 25                                              vsUTA
# 26                                             vsUAPB
# 27                                             vsCHIC
# 28                                               @WSU
# 29                                             vsSFSU
#
#                                                Result  \
# 0                                              L67-64
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                              W78-69
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                              W67-60
# ..                                                ...
# 25                                             L70-62
# 26                                             W86-58
# 27                                             W81-50
# 28                                             L73-65
# 29                                            W119-65
#
#                                                   MIN  \
# 0                                                   2
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                   9
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                   5
# ..                                                ...
# 25                                                 33
# 26                                                 24
# 27                                                 23
# 28                                                 33
# 29                                                 21
#
#                                                    FG  \
# 0                                                 0-1
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                 1-1
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                 0-1
# ..                                                ...
# 25                                              10-15
# 26                                               9-12
# 27                                                5-6
# 28                                               8-16
# 29                                               9-13
#
#                                                   FG%  \
# 0                                                 0.0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                               100.0
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                 0.0
# ..                                                ...
# 25                                               66.7
# 26                                               75.0
# 27                                               83.3
# 28                                               50.0
# 29                                               69.2
#
#                                                   3PT  \
# 0                                                 0-1
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                 1-1
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                 0-1
# ..                                                ...
# 25                                                1-1
# 26                                                0-0
# 27                                                1-1
# 28                                                0-1
# 29                                                1-1
#
#                                                   3P%  \
# 0                                                 0.0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                               100.0
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                 0.0
# ..                                                ...
# 25                                              100.0
# 26                                                0.0
# 27                                              100.0
# 28                                                0.0
# 29                                              100.0
#
#                                                    FT  \
# 0                                                 0-0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                 0-0
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                 0-0
# ..                                                ...
# 25                                                2-6
# 26                                                2-2
# 27                                                2-2
# 28                                               9-11
# 29                                                6-8
#
#                                                   FT%  \
# 0                                                 0.0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                 0.0
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                 0.0
# ..                                                ...
# 25                                               33.3
# 26                                              100.0
# 27                                              100.0
# 28                                               81.8
# 29                                               75.0
#
#                                                   REB  \
# 0                                                   0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                   0
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                   0
# ..                                                ...
# 25                                                  7
# 26                                                  9
# 27                                                  4
# 28                                                 11
# 29                                                  7
#
#                                                   AST  \
# 0                                                   0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                   1
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                   0
# ..                                                ...
# 25                                                  1
# 26                                                  0
# 27                                                  2
# 28                                                  0
# 29                                                  0
#
#                                                   BLK  \
# 0                                                   0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                   0
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                   0
# ..                                                ...
# 25                                                  0
# 26                                                  0
# 27                                                  1
# 28                                                  0
# 29                                                  2
#
#                                                   STL  \
# 0                                                   0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                   0
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                   0
# ..                                                ...
# 25                                                  0
# 26                                                  1
# 27                                                  1
# 28                                                  1
# 29                                                  0
#
#                                                    PF  \
# 0                                                   0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                   0
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                   1
# ..                                                ...
# 25                                                  3
# 26                                                  3
# 27                                                  3
# 28                                                  3
# 29                                                  2
#
#                                                    TO  \
# 0                                                   0
# 1    Hercules Tires Big West Championship - Semifinal
# 2                                                   0
# 3   Hercules Tires Big West Championship - Quarter...
# 4                                                   0
# ..                                                ...
# 25                                                  4
# 26                                                  1
# 27                                                  1
# 28                                                  1
# 29                                                  2
#
#                                                   PTS         Player
# 0                                                   0  cole-anderson
# 1    Hercules Tires Big West Championship - Semifinal  cole-anderson
# 2                                                   3  cole-anderson
# 3   Hercules Tires Big West Championship - Quarter...  cole-anderson
# 4                                                   0  cole-anderson
# ..                                                ...            ...
# 25                                                 23     amadou-sow
# 26                                                 20     amadou-sow
# 27                                                 13     amadou-sow
# 28                                                 25     amadou-sow
# 29                                                 25     amadou-sow
#
# [71 rows x 18 columns]

# %%
df = df[df["Date"].str.contains("Hercules") == False] #filter out rows that aren't game stats
df = df[df["Date"].str.contains("Skyline") == False]

# %%
def change_col_types(df):
    numcols_to_change = df.columns
    for col in numcols_to_change:
        try:
            df[col] = df[col].astype(float)
        except:
            continue

# %%
change_col_types(df)

# %%
total_df = df.groupby("Player").sum()
total_df
# Out:
#                  MIN     FG%    3P%     FT%    REB   AST   BLK   STL    PF  \
# Player
# amadou-sow     832.0  1601.9  758.3  1692.6  235.0  20.0  23.0  21.0  69.0
# ariel-bland     38.0   200.0    0.0     0.0    9.0   2.0   2.0   0.0   4.0
# cole-anderson  283.0  1002.7  845.3   450.0   19.0   9.0   0.0   6.0  22.0
# gage-gomez      11.0   100.0  100.0     0.0    3.0   2.0   0.0   0.0   0.0
#
#                  TO    PTS
# Player
# amadou-sow     55.0  438.0
# ariel-bland     2.0   10.0
# cole-anderson   6.0  111.0
# gage-gomez      0.0    3.0
